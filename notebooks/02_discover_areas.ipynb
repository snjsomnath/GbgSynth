# %% [markdown]
# # 02 · Discover Areas
#
# Browse all 96 primary areas (primärområden) in Gothenburg without making any API calls.

# %%
import logging
logging.basicConfig(level=logging.WARNING)

from gbgsynth import GbgSynth

city = GbgSynth(year=2023)

# %% [markdown]
# ### List area names and codes

# %%
names = city.list_areas()
print(f"Gothenburg has {len(names)} primary areas.\n")

for i, name in enumerate(names[:15], 1):
    code = city.get_area_code(name)
    print(f"  {code}  {name}")
print(f"  ...  ({len(names) - 15} more)")
# Out:
# Gothenburg has 96 primary areas.
#
#   101  Kungsladugård
#   102  Sanna
#   103  Majorna
#   104  Stigberget
#   105  Masthugget
#   106  Änggården
#   107  Haga
#   108  Annedal
#   109  Olivedal
#   110  Krokslätt
#   111  Johanneberg
#   112  Landala
#   113  Guldheden
#   114  Lorensberg
#   115  Vasastaden
#   ...  (81 more)

# %% [markdown]
# ### Look up by name or code

# %%
print(f"Code for 'Haga': {city.get_area_code('Haga')}")

all_areas = city.get_all_areas()
print(f"Name for '107':  {all_areas['107']}")
# Out:
# Code for 'Haga': 107
# Name for '107':  107 Haga
