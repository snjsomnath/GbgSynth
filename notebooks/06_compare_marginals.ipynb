# %% [markdown]
# # 06 · Compare to Census Marginals
#
# Check how well the synthetic population matches the real census distributions (age, sex, household size, housing type, etc.).

# %%
import logging
logging.basicConfig(level=logging.ERROR, format="%(message)s")

from gbgsynth import GbgSynth

city = GbgSynth(year=2023)
haga = city.synthesize("Haga")

# %% [markdown]
# ### Detailed comparison table

# %%
comparison = haga.compare_to_marginals(print_report=True)
# Out:
# ======================================================================
# MARGINAL COMPARISON REPORT: 107 Haga (2023)
# ======================================================================
#
# Sex Distribution
# --------------------------------------------------
# Category                 Actual      Synth     Diff    Error
# --------------------------------------------------
# Kvinna                     2047       2043       -4    -0.2%
# Man                        1768       1765       -3    -0.2%
# --------------------------------------------------
# TOTAL                      3815       3808       -7
#
# Age Distribution
# --------------------------------------------------
# Category                 Actual      Synth     Diff    Error
# --------------------------------------------------
# 0-5 år                      139        139       +0     0.0%
# 6-15 år                     338        338       +0     0.0%
# 16-18 år                    130        130       +0     0.0%
# 19-24 år                    215        214       -1    -0.5%
# 25-34 år                    304        303       -1    -0.3%
# 35-44 år                    454        454       +0     0.0%
# 45-54 år                    643        641       -2    -0.3%
# 55-64 år                    675        672       -3    -0.4%
# 65-74 år                    617        617       +0     0.0%
# 75-84 år                    252        252       +0     0.0%
# 85- år                       48         48       +0     0.0%
# --------------------------------------------------
# TOTAL                      3815       3808       -7
#
# Household Role Distribution
# --------------------------------------------------
# Category                 Actual      Synth     Diff    Error
# --------------------------------------------------
# Sammanboende               1969       2075     +106     5.4%
# Övriga hushåll              352        151     -201   -57.1%
# Uppgift saknas                0          0       +0     0.0%
# Ensamstående               1494       1582      +88     5.9%
# --------------------------------------------------
# TOTAL                      3815       3808       -7
#
# Household Size Distribution
# --------------------------------------------------
# Category                 Actual      Synth     Diff    Error
# --------------------------------------------------
# 1 person                    990        967      -23    -2.3%
# 2 personer                  625        629       +4     0.6%
# 3 personer                  245        245       +0     0.0%
# 4 personer                  136        138       +2     1.5%
# 5 personer                   43         47       +4     9.3%
# 6 eller fler perso           10         10       +0     0.0%
# Uppgift saknas                0          0       +0     0.0%
# --------------------------------------------------
# TOTAL                      2049       2036      -13
#
# Housing Type Distribution
# --------------------------------------------------
# Category                 Actual      Synth     Diff    Error
# --------------------------------------------------
# Specialbostad, övr           32         32       +0     0.0%
# Flerbostadshus             1992       1973      -19    -1.0%
# Uppgift saknas               18         23       +5    27.8%
# Småhus                        7          8       +1    14.3%
# --------------------------------------------------
# TOTAL                      2049       2036      -13
#
# Income Standard Distribution
# --------------------------------------------------
# Category                 Actual      Synth     Diff    Error
# --------------------------------------------------
# Ingår i helårshush          113         94      -19   -16.8%
# Ingår ej i helårsh           51          0      -51  -100.0%
# Ingår i helårshush         3642       3714      +72     2.0%
# --------------------------------------------------
# TOTAL                      3806       3808       +2
#
# ======================================================================
# OVERALL FIT STATISTICS
# ======================================================================
#   Total Population (Actual):  19,349
#   Total Population (Synth):   19,304
#   Categories Compared:        31
#   Root Mean Square Error:     47.01
#   Mean Absolute Error:        19.65
#   Max Category Error:         201
#   Pearson Correlation:        0.9987
#
#   Percentage Error Metrics:
#     MAPE (unweighted):        8.5%  ← treats all categories equally
#     Weighted MAPE:            3.1%  ← weighted by category size
#     Max Category Error:       100.0%
# ======================================================================

# %% [markdown]
# ### Overall fit metrics

# %%
ov = comparison["overall"]
print(f"RMSE:        {ov['rmse']:.2f}")
print(f"MAE:         {ov['mae']:.2f}")
print(f"MAPE:        {ov.get('mape', 0):.1f}%")
print(f"Correlation: {ov['correlation']:.4f}")
# Out:
# RMSE:        47.01
# MAE:         19.65
# MAPE:        8.5%
# Correlation: 0.9987
