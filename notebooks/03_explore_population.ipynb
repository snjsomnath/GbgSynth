# %% [markdown]
# # 03 · Explore a Population
#
# Generate a neighbourhood and explore individuals, households, and dwellings using the built-in DataFrame properties.

# %%
import logging
logging.basicConfig(level=logging.ERROR)

from gbgsynth import GbgSynth

city = GbgSynth(year=2023)
haga = city.synthesize("Haga")

# %% [markdown]
# ### Individuals

# %%
ind = haga.individuals_df
print(f"Columns: {list(ind.columns)}")
print(f"\nSex distribution:\n{ind['sex'].value_counts().to_string()}\n")
print(f"Household roles:\n{ind['hh_role'].value_counts().to_string()}\n")
print(f"Age quartiles:\n{ind['age'].describe().to_string()}")
# Out:
# Columns: ['agent_id', 'age', 'sex', 'hh_role', 'status', 'income', 'income_decile', 'income_source', 'education', 'household_id', 'area_code', 'area_name', 'year']
#
# Sex distribution:
# sex
# female    2043
# male      1765
#
# Household roles:
# hh_role
# cohabiting       1548
# single            990
# child             845
# single_parent     219
# other             206
#
# Age quartiles:
# count    3808.000000
# mean       46.474265
# std        22.502917
# min         0.000000
# 25%        29.000000
# 50%        50.000000
# 75%        64.000000
# max       100.000000

# %% [markdown]
# ### Households

# %%
hh = haga.households_df
print(f"Columns: {list(hh.columns)}")
print(f"\nSize distribution:\n{hh['size'].value_counts().sort_index().to_string()}")
# Out:
# Columns: ['household_id', 'size', 'actual_size', 'house_type', 'assigned_hustyp', 'building_id', 'dwelling_id', 'floor_area', 'cars', 'head_id', 'partner_id', 'child_ids', 'num_children', 'num_adults', 'total_income', 'is_couple', 'is_single_parent', 'area_code', 'area_name', 'year']
#
# Size distribution:
# size
# 1    974
# 2    628
# 3    248
# 4    136
# 5     46
# 6     10

# %% [markdown]
# ### Raw model objects

# %%
sample_hh = haga.households[0]
print(f"First household object: {sample_hh}")
if sample_hh.members:
    print(f"  Head: {sample_hh.head}")
    print(f"  Members: {[str(m) for m in sample_hh.members]}")
# Out:
# First household object: Household(id=1, 6/6 members, Flerbostadshus)
#   Head: Agent(id=2337, 62y M, cohabiting, hh=1)
#   Members: ['Agent(id=2337, 62y M, cohabiting, hh=1)', 'Agent(id=2575, 62y F, cohabiting, hh=1)', 'Agent(id=632, 19y M, child, hh=1)', 'Agent(id=771, 19y F, child, hh=1)', 'Agent(id=744, 20y F, child, hh=1)', 'Agent(id=668, 20y M, child, hh=1)']
